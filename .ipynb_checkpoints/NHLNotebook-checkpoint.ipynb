# %%
# WANT: Proj SOG

# Model:

# - SOG/GP TY
# - SOG/GP L3-L5
# - Opp Team Allowed SOG/GP TY
# - Opp Team Allowed SOG/GP L3-L5

# Additional:

# - Any Starting Opp D out
# - Starting Opp G out
# - Back to back games
# - Home vs Away
# - Penalties

homeTeam = "WPG"
awayTeam = "COL"

# %%
# GET TEAM DATA FOR ROSTER PROJ SOG

import pandas as pd

teamUrl = "https://www.hockey-reference.com/teams/" + homeTeam + "/"
fullPageData = pd.read_html(teamUrl)
homeTeamData = fullPageData[1]
homeRosterData = fullPageData[4]
homeRosterData.columns = homeRosterData.columns.droplevel()

# Average shots per game
homeAvgS = homeTeamData['S'].iloc[0] / homeTeamData['GP'].iloc[0]

homeSA = homeTeamData['SA'].iloc[0] / homeTeamData['GP'].iloc[0]
print(f"Opp SA avg: {homeSA}")

SGPData = homeRosterData.loc[:,["Player", "GP","S"]]
SGPData['S/GP'] = SGPData['S']/SGPData['GP']
SGPData.drop(SGPData.tail(1).index,inplace=True)
SGPData['S/GP'] = pd.to_numeric(SGPData['S/GP'])
SGPData = SGPData.loc[SGPData['S/GP'] >= 1.5]
SGPData['H/A'] = 'H'
SGPData
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       3 import pandas as pd
#       5 teamUrl = "https://www.hockey-reference.com/teams/" + homeTeam + "/"
# ----> 6 fullPageData = pd.read_html(teamUrl)
#       7 homeTeamData = fullPageData[1]
#       8 homeRosterData = fullPageData[4]
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:1098, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1094 validate_header_arg(header)
#    1096 io = stringify_path(io)
# -> 1098 return _parse(
#    1099     flavor=flavor,
#    1100     io=io,
#    1101     match=match,
#    1102     header=header,
#    1103     index_col=index_col,
#    1104     skiprows=skiprows,
#    1105     parse_dates=parse_dates,
#    1106     thousands=thousands,
#    1107     attrs=attrs,
#    1108     encoding=encoding,
#    1109     decimal=decimal,
#    1110     converters=converters,
#    1111     na_values=na_values,
#    1112     keep_default_na=keep_default_na,
#    1113     displayed_only=displayed_only,
#    1114 )
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:906, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     903 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     905 try:
# --> 906     tables = p.parse_tables()
#     907 except ValueError as caught:
#     908     # if `io` is an io-like object, check if it's seekable
#     909     # and try to rewind it before trying the next parser
#     910     if hasattr(io, "seekable") and io.seekable():
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:222, in _HtmlFrameParser.parse_tables(self)
#     214 def parse_tables(self):
#     215     """
#     216     Parse and return all tables from the DOM.
#     217
#    (...)
#     220     list of parsed (header, body, footer) tuples from tables.
#     221     """
# --> 222     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:745, in _LxmlFrameParser._build_doc(self)
#     743             pass
#     744     else:
# --> 745         raise e
#     746 else:
#     747     if not hasattr(r, "text_content"):
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:726, in _LxmlFrameParser._build_doc(self)
#     724 try:
#     725     if is_url(self.io):
# --> 726         with urlopen(self.io) as f:
#     727             r = parse(f, parser=parser)
#     728     else:
#     729         # try to parse the input in the simplest way
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/common.py:212, in urlopen(*args, **kwargs)
#     206 """
#     207 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     208 the stdlib.
#     209 """
#     210 import urllib.request
# --> 212 return urllib.request.urlopen(*args, **kwargs)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
# GET OPPONENT DATA
# INCLUDES:
#  -  OPPONENTS SHOTS ALLOWED AVERAGE
#  -  LEAGUE SHOTS ALLOWED AVERAGE

awayUrl = "https://www.hockey-reference.com/teams/" + awayTeam + "/"
awayFullPageData = pd.read_html(awayUrl)
awayTeamData = awayFullPageData[1]
awayRosterData = awayFullPageData[4]
awayRosterData.columns = awayRosterData.columns.droplevel()

# Average shots per game
awayAvgS = awayTeamData['S'].iloc[0] / awayTeamData['GP'].iloc[0]

awaySA = awayTeamData['SA'].iloc[0] / awayTeamData['GP'].iloc[0]
leagueAvgSA = awayTeamData['SA'].iloc[1] / awayTeamData['GP'].iloc[1]
print(f"Opp SA avg: {awaySA}")
print(f"League SA avg: {leagueAvgSA}")

awayData = awayRosterData.loc[:,["Player", "GP","S"]]
awayData['S/GP'] = awayData['S']/awayData['GP']
awayData.drop(awayData.tail(1).index,inplace=True)
awayData['S/GP'] = pd.to_numeric(awayData['S/GP'])
awayData = awayData.loc[awayData['S/GP'] >= 1.5]
awayData['H/A'] = 'A'
SGPData = pd.concat([SGPData, awayData], axis=0)
SGPData
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       1 # GET OPPONENT DATA
#       2 # INCLUDES:
#       3 #  -  OPPONENTS SHOTS ALLOWED AVERAGE
#       4 #  -  LEAGUE SHOTS ALLOWED AVERAGE
#       6 awayUrl = "https://www.hockey-reference.com/teams/" + awayTeam + "/"
# ----> 7 awayFullPageData = pd.read_html(awayUrl)
#       8 awayTeamData = awayFullPageData[1]
#       9 awayRosterData = awayFullPageData[4]
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:1098, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1094 validate_header_arg(header)
#    1096 io = stringify_path(io)
# -> 1098 return _parse(
#    1099     flavor=flavor,
#    1100     io=io,
#    1101     match=match,
#    1102     header=header,
#    1103     index_col=index_col,
#    1104     skiprows=skiprows,
#    1105     parse_dates=parse_dates,
#    1106     thousands=thousands,
#    1107     attrs=attrs,
#    1108     encoding=encoding,
#    1109     decimal=decimal,
#    1110     converters=converters,
#    1111     na_values=na_values,
#    1112     keep_default_na=keep_default_na,
#    1113     displayed_only=displayed_only,
#    1114 )
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:906, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     903 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     905 try:
# --> 906     tables = p.parse_tables()
#     907 except ValueError as caught:
#     908     # if `io` is an io-like object, check if it's seekable
#     909     # and try to rewind it before trying the next parser
#     910     if hasattr(io, "seekable") and io.seekable():
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:222, in _HtmlFrameParser.parse_tables(self)
#     214 def parse_tables(self):
#     215     """
#     216     Parse and return all tables from the DOM.
#     217
#    (...)
#     220     list of parsed (header, body, footer) tuples from tables.
#     221     """
# --> 222     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:745, in _LxmlFrameParser._build_doc(self)
#     743             pass
#     744     else:
# --> 745         raise e
#     746 else:
#     747     if not hasattr(r, "text_content"):
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:726, in _LxmlFrameParser._build_doc(self)
#     724 try:
#     725     if is_url(self.io):
# --> 726         with urlopen(self.io) as f:
#     727             r = parse(f, parser=parser)
#     728     else:
#     729         # try to parse the input in the simplest way
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/common.py:212, in urlopen(*args, **kwargs)
#     206 """
#     207 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     208 the stdlib.
#     209 """
#     210 import urllib.request
# --> 212 return urllib.request.urlopen(*args, **kwargs)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
# GET AVG SOG OF LAST 5 GAME
# GET PERCENT OF SOG BASED ON TEAM TOTAL AVG SOG
# GET PERCENT OF SOG BASED ON TEAM TOTAL AVG SOG AND LAST 5 GAME AVG SOG

import numpy as np

playerL5AVG = []
playerTeamSPerc = []
playerTeamSPercL5 = []
for index, row in SGPData.iterrows():
    player = row['Player']
    sGP = row['S/GP']
    homeAway = row['H/A']
    if (homeAway == 'H'):
        playerTeamSPerc.append((sGP/homeAvgS)*100)
    else:
        playerTeamSPerc.append((sGP/awayAvgS)*100)
    print(player)
    url = 'https://www.hockey-reference.com/players/'
    nameSplit = player.split()
    url += nameSplit[1][0]
    url += '/'
    url += nameSplit[1][:5]
    url += nameSplit[0][:2]
    url += '01.html'
    url = url.lower()
    print(url)
    try:
        playerL5 = pd.read_html(url, encoding="iso-8859-1")
        playerL5 = playerL5[0]
        playerL5.columns = playerL5.columns.droplevel()
        playerL5.drop(playerL5.tail(1).index,inplace=True)
        playerL5 = pd.to_numeric(playerL5.loc[:,"S"])
        if (playerL5.mean() > 10):
            playerL5AVG.append(np.nan)
            playerTeamSPercL5.append(np.nan)
        else:
            playerL5AVG.append(playerL5.mean())
            if (homeAway == 'H'):
                playerTeamSPercL5.append((playerL5.mean()/homeAvgS)*100)
            else:
                playerTeamSPercL5.append((playerL5.mean()/awayAvgS)*100)
    except:
        playerL5AVG.append(np.nan)
        playerTeamSPercL5.append(np.nan)



SGPData["S/GP L5"] = playerL5AVG
SGPData["S/GP Team %"] = playerTeamSPerc
SGPData["S/GP L5 Team %"] = playerTeamSPercL5
SGPData
# Out:
# Kyle Connor
# https://www.hockey-reference.com/players/c/connoky01.html
# Josh Morrissey
# https://www.hockey-reference.com/players/m/morrijo01.html
# Pierre-Luc Dubois
# https://www.hockey-reference.com/players/d/duboipi01.html
# Mark Scheifele
# https://www.hockey-reference.com/players/s/scheima01.html
# Blake Wheeler
# https://www.hockey-reference.com/players/w/wheelbl01.html
# Cole Perfetti
# https://www.hockey-reference.com/players/p/perfeco01.html
# Neal Pionk
# https://www.hockey-reference.com/players/p/pionkne01.html
# Nikolaj Ehlers
# https://www.hockey-reference.com/players/e/ehlerni01.html
# Sam Gagner
# https://www.hockey-reference.com/players/g/gagnesa01.html
# Morgan Barron
# https://www.hockey-reference.com/players/b/barromo01.html
# Nathan MacKinnon
# https://www.hockey-reference.com/players/m/mackina01.html
# Mikko Rantanen
# https://www.hockey-reference.com/players/r/rantami01.html
# Cale Makar
# https://www.hockey-reference.com/players/m/makarca01.html
# Artturi Lehkonen
# https://www.hockey-reference.com/players/l/lehkoar01.html
# J.T. Compher
# https://www.hockey-reference.com/players/c/comphj.01.html
# Devon Toews
# https://www.hockey-reference.com/players/t/toewsde01.html
# Evan Rodrigues
# https://www.hockey-reference.com/players/r/rodriev01.html
# Samuel Girard
# https://www.hockey-reference.com/players/g/girarsa01.html
# Valeri Nichushkin
# https://www.hockey-reference.com/players/n/nichuva01.html
# Erik Johnson
# https://www.hockey-reference.com/players/j/johnser01.html
# Matthew Nieto
# https://www.hockey-reference.com/players/n/nietoma01.html
# Charles Hudon
# https://www.hockey-reference.com/players/h/hudonch01.html
# Nathan MacKinnon
# https://www.hockey-reference.com/players/m/mackina01.html
# Mikko Rantanen
# https://www.hockey-reference.com/players/r/rantami01.html
# Cale Makar
# https://www.hockey-reference.com/players/m/makarca01.html
# Artturi Lehkonen
# https://www.hockey-reference.com/players/l/lehkoar01.html
# J.T. Compher
# https://www.hockey-reference.com/players/c/comphj.01.html
# Devon Toews
# https://www.hockey-reference.com/players/t/toewsde01.html
# Evan Rodrigues
# https://www.hockey-reference.com/players/r/rodriev01.html
# Samuel Girard
# https://www.hockey-reference.com/players/g/girarsa01.html
# Valeri Nichushkin
# https://www.hockey-reference.com/players/n/nichuva01.html
# Erik Johnson
# https://www.hockey-reference.com/players/j/johnser01.html
# Matthew Nieto
# https://www.hockey-reference.com/players/n/nietoma01.html
# Charles Hudon
# https://www.hockey-reference.com/players/h/hudonch01.html
#                Player  GP    S      S/GP H/A  S/GP L5  S/GP Team %  \
# 0         Kyle Connor  58  201  3.465517   H      NaN    11.498856
# 1      Josh Morrissey  58  117  2.017241   H      NaN     6.693364
# 2   Pierre-Luc Dubois  58  166  2.862069   H      NaN     9.496568
# 3      Mark Scheifele  58  156  2.689655   H      NaN     8.924485
# 4       Blake Wheeler  49   87  1.775510   H      NaN     5.891281
# 5       Cole Perfetti  51   90  1.764706   H      NaN     5.855431
# 6          Neal Pionk  58  103  1.775862   H      NaN     5.892449
# 8      Nikolaj Ehlers  22   71  3.227273   H      NaN    10.708342
# 11         Sam Gagner  46   74  1.608696   H      NaN     5.337777
# 12      Morgan Barron  46   75  1.630435   H      NaN     5.409909
# 0    Nathan MacKinnon  44  236  5.363636   A      NaN    16.032609
# 1      Mikko Rantanen  55  209  3.800000   A      NaN    11.358696
# 2          Cale Makar  46  142  3.086957   A      NaN     9.227316
# 3    Artturi Lehkonen  52  124  2.384615   A      NaN     7.127926
# 4        J.T. Compher  55  108  1.963636   A      NaN     5.869565
# 5         Devon Toews  53  105  1.981132   A      NaN     5.921862
# 6      Evan Rodrigues  44  135  3.068182   A      NaN     9.171196
# 7       Samuel Girard  49   80  1.632653   A      NaN     4.880213
# 8   Valeri Nichushkin  27   85  3.148148   A      NaN     9.410225
# 14       Erik Johnson  51   80  1.568627   A      NaN     4.688832
# 20      Matthew Nieto   9   16  1.777778   A      NaN     5.314010
# 33      Charles Hudon   9   18  2.000000   A      NaN     5.978261
# 0    Nathan MacKinnon  44  236  5.363636   A      NaN    16.032609
# 1      Mikko Rantanen  55  209  3.800000   A      NaN    11.358696
# 2          Cale Makar  46  142  3.086957   A      NaN     9.227316
# 3    Artturi Lehkonen  52  124  2.384615   A      NaN     7.127926
# 4        J.T. Compher  55  108  1.963636   A      NaN     5.869565
# 5         Devon Toews  53  105  1.981132   A      NaN     5.921862
# 6      Evan Rodrigues  44  135  3.068182   A      NaN     9.171196
# 7       Samuel Girard  49   80  1.632653   A      NaN     4.880213
# 8   Valeri Nichushkin  27   85  3.148148   A      NaN     9.410225
# 14       Erik Johnson  51   80  1.568627   A      NaN     4.688832
# 20      Matthew Nieto   9   16  1.777778   A      NaN     5.314010
# 33      Charles Hudon   9   18  2.000000   A      NaN     5.978261
#
#     S/GP L5 Team %
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 8              NaN
# 11             NaN
# 12             NaN
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 14             NaN
# 20             NaN
# 33             NaN
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 14             NaN
# 20             NaN
# 33             NaN

# %% [markdown]
# TEMPLATE MATH:
#
# Opponents Allowed SOG Avg
#
# Example : 35.23
#
# Avg SOG
#
# Example: 35.4
#
# Toffoli Avg:
#
# ~ 8.7% of the SOG for team
#
# 8.7% of 35.23 = Proj 3.065 SOG
#
# Toffoli AVG L5:
#
# ~ 9.6%
#
# 9.6% of 35.23 = 3.382 SOG
#
# AVG OF ALL SOG AVGS:
#
# 3.382 + 3.065 + 3.070 + 3.4 = Aggregate project SOG 3.229

# %%
# GETS PROJECTED SOG BASED ON AVG PERCENT OF SOG FROM TEAM TOTAL AND ALLOWED SOG FROM OPPONENT
# GETS SAME AS ABOVE, JUST L5 GAMES

projSOG = []
projSOGL5 = []
for index, row in SGPData.iterrows():
    sPerc = row['S/GP Team %']/100
    sPercL5 = row['S/GP L5 Team %']/100
    projSOG.append(sPerc*oppSA)
    projSOGL5.append(sPercL5*oppSA)
    
SGPData["Proj S"] = projSOG
SGPData["Proj S L5"] = projSOGL5
SGPData
# Out:
#                Player  GP    S      S/GP  S/GP L5  S/GP Team %  \
# 0         Kyle Connor  58  201  3.465517      3.8    11.498856
# 1      Josh Morrissey  58  117  2.017241      NaN     6.693364
# 2   Pierre-Luc Dubois  58  166  2.862069      2.6     9.496568
# 3      Mark Scheifele  58  156  2.689655      3.0     8.924485
# 4       Blake Wheeler  49   87  1.775510      1.0     5.891281
# 5       Cole Perfetti  51   90  1.764706      1.4     5.855431
# 6          Neal Pionk  58  103  1.775862      1.8     5.892449
# 8      Nikolaj Ehlers  22   71  3.227273      3.4    10.708342
# 11         Sam Gagner  46   74  1.608696      0.8     5.337777
# 12      Morgan Barron  46   75  1.630435      1.6     5.409909
#
#     S/GP L5 Team %    Proj S  Proj S L5
# 0        12.608696  3.725629   4.085217
# 1              NaN  2.168650        NaN
# 2         8.627002  3.076888   2.795149
# 3         9.954233  2.891533   3.225172
# 4         3.318078  1.908775   1.075057
# 5         4.645309  1.897160   1.505080
# 6         5.972540  1.909153   1.935103
# 8        11.281465  3.469503   3.655195
# 11        2.654462  1.729440   0.860046
# 12        5.308924  1.752811   1.720092

# %%
# GETS AGGREGATE PROJ SOG BASED ON THE STATS BELOW
#  -  AVG SOG
#  -  AVG SOG L5 GAMES
#  -  PROJ SOG BASED ON OPPONENT AND WHOLE SEASON
#  -  PROJ SOG BASED ON OPPONENT AND AVG L5 GAMES

aggProjSOG = []
for index, row in SGPData.iterrows():
    aggProj = row['S/GP'] + row['S/GP L5'] + row['Proj S'] + row['Proj S L5']
    aggProjSOG.append(aggProj/4)
    
SGPData["Agg Proj S"] = aggProjSOG
SGPData
# Out:
#                Player  GP    S      S/GP  S/GP L5  S/GP Team %  \
# 0         Kyle Connor  58  201  3.465517      3.8    11.498856
# 1      Josh Morrissey  58  117  2.017241      NaN     6.693364
# 2   Pierre-Luc Dubois  58  166  2.862069      2.6     9.496568
# 3      Mark Scheifele  58  156  2.689655      3.0     8.924485
# 4       Blake Wheeler  49   87  1.775510      1.0     5.891281
# 5       Cole Perfetti  51   90  1.764706      1.4     5.855431
# 6          Neal Pionk  58  103  1.775862      1.8     5.892449
# 8      Nikolaj Ehlers  22   71  3.227273      3.4    10.708342
# 11         Sam Gagner  46   74  1.608696      0.8     5.337777
# 12      Morgan Barron  46   75  1.630435      1.6     5.409909
#
#     S/GP L5 Team %    Proj S  Proj S L5  Agg Proj S
# 0        12.608696  3.725629   4.085217    3.769091
# 1              NaN  2.168650        NaN         NaN
# 2         8.627002  3.076888   2.795149    2.833526
# 3         9.954233  2.891533   3.225172    2.951590
# 4         3.318078  1.908775   1.075057    1.439836
# 5         4.645309  1.897160   1.505080    1.641736
# 6         5.972540  1.909153   1.935103    1.855030
# 8        11.281465  3.469503   3.655195    3.437993
# 11        2.654462  1.729440   0.860046    1.249545
# 12        5.308924  1.752811   1.720092    1.675834
